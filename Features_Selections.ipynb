# %% [markdown]
# # Features Selection

# %% [markdown]
#
# This algorithm creates a list of all possible combinations of features.
# Next the algorithm iterates over the list, trains the model, and evaluates it.
# The algorithm collects accuracies and features into a list, sorts them, and displays them.
# ### Attention :)
# Number_of_accuracies = 2 ** quantity_of_features

# %%
import pandas as pd
import numpy as np

import os
path = os.path.expanduser("~/Documents/useful_df_car_accident_severity.csv")
df = pd.read_csv (path)

df.head(2)

# %%
X = df[['X', 'Y',
        'ADDRTYPE', 'INTKEY',
        'COLLISIONTYPE', 'PERSONCOUNT',
        'PEDCOUNT', 'PEDCYLCOUNT', 'VEHCOUNT',
        'JUNCTIONTYPE', 'SDOT_COLCODE', 'INATTENTIONIND', 
        'UNDERINFL', 'WEATHER', 'ROADCOND', 'LIGHTCOND',
        'PEDROWNOTGRNT', 'SPEEDING',
        'SEGLANEKEY', 'CROSSWALKKEY', 'HITPARKEDCAR',
        'year', 'month', 'day', 'hour', 'minute', 'weekday_name']]

y = df['SEVERITYCODE']

# %% [markdown]
# # Examples

# %% [markdown]
# ### DecisionTreeClassifier

# %%
X = ['X', 'Y', 'SEGLANEKEY', 'ROADCOND', 'LIGHTCOND', 'hour', 'weekday_name']    # type list !!!

y = df['SEVERITYCODE']    # df


def get_combinations(X):
    '''get all combinations of X features'''
    import itertools
    global combinations
    combinations = []
    for L in range(0, len(X)+1):
         for subset in itertools.combinations(X, L):
            subset = list(subset)
            combinations.append(subset)
    del combinations[0]
    return combinations


def iterative_evaluation(df, y, combinations):
    '''iterative evaluation of all features'''
    comand = input(f'You have {len(combinations)} combinations of X features.'
                   f' Input y/n for continuous (+ press enter/return)')
    if comand == 'n':
        return 'OK'
    elif comand == 'y':
        
# Imports _________________________________________________________
        from sklearn.model_selection import train_test_split
        from sklearn.tree import DecisionTreeClassifier
        from sklearn import metrics
        
# Classifier Entity _______________________________________________
        Tree = DecisionTreeClassifier(criterion="entropy")
        
        global evaluations
        evaluations = []
        i=1
        
        for el in combinations:
            print(f'Inprogress {i}/{len(combinations)}')
            el = list(el)
            X = df[el]
            
# Model train and evaluation ______________________________________
            X_trainset, X_testset, y_trainset, y_testset = train_test_split(X, y, test_size=0.1, random_state=3)
            Tree.fit(X_trainset,y_trainset)            
            predTree = Tree.predict(X_testset)
            accuracy = metrics.accuracy_score(y_testset, predTree)
            
            evaluations.append([accuracy, el])
            i+=1             
        return get_sorted_evaluations(evaluations)
    else:
        return 'False'

    
def get_sorted_evaluations(evaluations):
    '''sort and show list of evaluations'''
    evaluations.sort(reverse=True)
    print("")
    print("___DecisionTreeClassifier  SORTED  EVALUATIONS:___")
    print("")
    print(f"{len(evaluations)} evaluations")
    print("")
    for el in evaluations:
        print(el)
        print("")

        
get_combinations(X) 
iterative_evaluation(df, y, combinations)
# Out:
# You have 127 combinations of X features. Input y/n for continuous (+ press enter/return) y
# Inprogress 1/127
# Inprogress 2/127
# Inprogress 3/127
# Inprogress 4/127
# Inprogress 5/127
# Inprogress 6/127
# Inprogress 7/127
# Inprogress 8/127
# Inprogress 9/127
# Inprogress 10/127
# Inprogress 11/127
# Inprogress 12/127
# Inprogress 13/127
# Inprogress 14/127
# Inprogress 15/127
# Inprogress 16/127
# Inprogress 17/127
# Inprogress 18/127
# Inprogress 19/127
# Inprogress 20/127
# Inprogress 21/127
# Inprogress 22/127
# Inprogress 23/127
# Inprogress 24/127
# Inprogress 25/127
# Inprogress 26/127
# Inprogress 27/127
# Inprogress 28/127
# Inprogress 29/127
# Inprogress 30/127
# Inprogress 31/127
# Inprogress 32/127
# Inprogress 33/127
# Inprogress 34/127
# Inprogress 35/127
# Inprogress 36/127
# Inprogress 37/127
# Inprogress 38/127
# Inprogress 39/127
# Inprogress 40/127
# Inprogress 41/127
# Inprogress 42/127
# Inprogress 43/127
# Inprogress 44/127
# Inprogress 45/127
# ...

# %% [markdown]
# ### LGBMClassifier

# %%
# type list !!!
X = ['X', 'Y', 'INTKEY', 'JUNCTIONTYPE', 'PEDROWNOTGRNT', 'SEGLANEKEY', 'CROSSWALKKEY']

# type df
y = df['SEVERITYCODE']


def get_combinations(X):
    '''get all combinations of X features'''
    import itertools
    global combinations
    combinations = []
    for L in range(0, len(X)+1):
         for subset in itertools.combinations(X, L):
            subset = list(subset)
            combinations.append(subset)
    del combinations[0]
    return combinations


def iterative_evaluation(df, y, combinations):
    '''iterative evaluation of all features'''
    comand = input(f'You have {len(combinations)} combinations of X features.'
                   f' Input y/n for continuous (+ press enter/return)')
    if comand == 'n':
        return 'OK'
    elif comand == 'y':
# Imports
        import lightgbm as lgb
        from sklearn.model_selection import train_test_split
        from sklearn import metrics
# Classifier Entity        
        lgbm = lgb.LGBMClassifier()
        
        global evaluations
        evaluations = []
        i=1
        
        for el in combinations:
            print(f'Inprogress {i}/{len(combinations)}')
            el = list(el)
            X = df[el]            
# Model evaluation
            X_trainset, X_testset, y_trainset, y_testset = train_test_split(X, y, test_size=0.1, random_state=3)
    
            lgbm.fit(X_trainset,y_trainset)
            predTree = lgbm.predict(X_testset)
            accuracy = metrics.accuracy_score(y_testset, predTree)
            
            evaluations.append([accuracy, el])
            i+=1             
        return get_sorted_evaluations(evaluations)
    else:
        return 'False'

    
def get_sorted_evaluations(evaluations):
    '''sort and show list of evaluations'''
    evaluations.sort(reverse=True)
    print("")
    print("___DecisionTreeClassifier  SORTED  EVALUATIONS:___")
    print("")
    print(f"{len(evaluations)} evaluations")
    print("")
    for el in evaluations:
        print(el)
        print("")

        
get_combinations(X) 
iterative_evaluation(df, y, combinations)
# Out:
# You have 127 combinations of X features. Input y/n for continuous (+ press enter/return) y
# /Users/artyomkolas/opt/anaconda3/envs/ibm/lib/python3.8/site-packages/lightgbm/__init__.py:42: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_8.3.3) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   warnings.warn("Starting from version 2.2.1, the library file in distribution wheels for macOS "
# Inprogress 1/127
# Inprogress 2/127
# Inprogress 3/127
# Inprogress 4/127
# Inprogress 5/127
# Inprogress 6/127
# Inprogress 7/127
# Inprogress 8/127
# Inprogress 9/127
# ...

# %% [markdown]
# # Results

# %%
# DecisionTreeClassifier

# All features
['X', 'Y', 'ADDRTYPE', 'INTKEY', 'COLLISIONTYPE', 'PERSONCOUNT', 'PEDCOUNT', 'PEDCYLCOUNT', 'VEHCOUNT',
 'JUNCTIONTYPE', 'SDOT_COLCODE', 'INATTENTIONIND', 'UNDERINFL', 'WEATHER', 'ROADCOND', 'LIGHTCOND', 'PEDROWNOTGRNT', 'SPEEDING',
 'SEGLANEKEY', 'CROSSWALKKEY', 'HITPARKEDCAR', 'year', 'month', 'day', 'hour', 'minute', 'weekday_name']
Accuracy: 0.6853807964508292


[['ADDRTYPE', 'COLLISIONTYPE', 'PEDCOUNT', 'VEHCOUNT', 'SDOT_COLCODE', 'UNDERINFL']]
Accuracy: 0.7573676983204817



# LGBMClassifier

# All features
['X', 'Y', 'ADDRTYPE', 'INTKEY', 'COLLISIONTYPE', 'PERSONCOUNT', 'PEDCOUNT', 'PEDCYLCOUNT', 'VEHCOUNT',
 'JUNCTIONTYPE', 'SDOT_COLCODE', 'INATTENTIONIND', 'UNDERINFL', 'WEATHER', 'ROADCOND', 'LIGHTCOND', 'PEDROWNOTGRNT', 'SPEEDING',
 'SEGLANEKEY', 'CROSSWALKKEY', 'HITPARKEDCAR', 'year', 'month', 'day', 'hour', 'minute', 'weekday_name']
Accuracy: 0.7610119361994296

    
# All features without ['day']
[['X', 'Y', 'ADDRTYPE', 'INTKEY', 'COLLISIONTYPE', 'PERSONCOUNT', 'PEDCOUNT', 'PEDCYLCOUNT', 'VEHCOUNT',
 'JUNCTIONTYPE', 'SDOT_COLCODE', 'INATTENTIONIND', 'UNDERINFL', 'WEATHER', 'ROADCOND', 'LIGHTCOND', 'PEDROWNOTGRNT', 'SPEEDING',
 'SEGLANEKEY', 'CROSSWALKKEY', 'HITPARKEDCAR', 'year', 'month', 'hour', 'minute', 'weekday_name']]
Accuracy: 0.7611175662828774
# Out:
# 0.7610119361994296
